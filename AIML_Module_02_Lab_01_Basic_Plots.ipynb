# %% [markdown]
# <a href="https://colab.research.google.com/github/geethikaprasad13/AIML_Projects_and_Lab/blob/main/AIML_Module_02_Lab_01_Basic_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url = "https://raw.githubusercontent.com/SP9144/FMML_Data/main/Automobile_data.csv"
response = requests.get(url)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from io import StringIO
import matplotlib.pyplot as plt

# %%
data = StringIO(response.text)
data = pd.read_csv(data)
print("Number of data points =", len(data))
data.head()
# Out:
# Number of data points = 205
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.replace("?", np.nan, inplace = True)
data = data.dropna()
print(len(data))
# Out:
# 159

# %%
X = data.drop("price", axis = 1)
y = pd.to_numeric(data["price"])

# %%
plt.figure(figsize = (24, 7))
plt.scatter(X["make"], y)
plt.xlabel('Make')
plt.ylabel('Price')
plt.title('Car maker vs Price - Scatter Plot')
plt.show()

# %%
sns.set(rc={'figure.figsize':(24,7)})
sns.boxplot(x=X["make"],y=y, palette="Set3").set_title('Car Manufacturer vs Price - Box Plot')
# Out:
# /tmp/ipython-input-8-892029043.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=X["make"],y=y, palette="Set3").set_title('Car Manufacturer vs Price - Box Plot')
# Text(0.5, 1.0, 'Car Manufacturer vs Price - Box Plot')

# %%
sns.violinplot(x=X["make"],y=y, palette="Set3").set_title('Car maker vs Price - Violin Plot')
# Out:
# /tmp/ipython-input-9-1862270216.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=X["make"],y=y, palette="Set3").set_title('Car maker vs Price - Violin Plot')
# Text(0.5, 1.0, 'Car maker vs Price - Violin Plot')

# %%
sns.swarmplot(x=X["make"],y=y).set_title('Car maker vs Price Swarm Plot')
# Out:
# Text(0.5, 1.0, 'Car maker vs Price Swarm Plot')

# %%
sns.boxplot(x=X["make"],y=pd.to_numeric(X["horsepower"]), palette="Set3").set_title('Car maker vs Horsepower Box Plot')
# Out:
# /tmp/ipython-input-11-541565243.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=X["make"],y=pd.to_numeric(X["horsepower"]), palette="Set3").set_title('Car maker vs Horsepower Box Plot')
# Text(0.5, 1.0, 'Car maker vs Horsepower Box Plot')

# %%
sns.set(rc={'figure.figsize':(7,5)})
sns.scatterplot(x=pd.to_numeric(X["horsepower"]), y = y, color = "red")
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %%
sns.jointplot(x=pd.to_numeric(X["horsepower"]), y = y, kind="reg", color = 'green')

# %%
feature = "city-mpg"
sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'blue')

# %% [markdown]
# 1. From the plot, convertibles have the highest median price.Hardtops and wagons also show some higher price points, but convertibles are consistently on the higher end.
#
# 2. No, maximum and minimum values alone can be misleading.The interquartile range (IQR) tells us where most cars fall in terms of price. For example, sedans have a wide IQR, indicating a broad price range, while convertibles have a tight but high IQR, showing they are consistently expensive. So, using median and IQR gives a better idea of which body-type is costliest.
#
# 3. Partially yes. Some body-styles (like convertibles and hatchbacks) show a clear price tendency. But many body-styles (like sedans, wagons) overlap in price range. So while body-style gives some predictive value, it's not sufficient alone to accurately predict price — we need to combine it with other features like make, horsepower, engine size, etc.

# %%
sns.boxplot(x=X["body-style"],y=y, palette="Set3").set_title('Body style vs Price Box Plot')
# Out:
# /tmp/ipython-input-15-1765729027.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=X["body-style"],y=y, palette="Set3").set_title('Body style vs Price Box Plot')
# Text(0.5, 1.0, 'Body style vs Price Box Plot')

# %%
# Exercise 1:
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Plot 1: Box Plot
sns.boxplot(x=X["make"], y=y, palette="Set2", ax=axes[0])
axes[0].set_title("Boxplot: Car Make vs Price")

# Plot 2: Violin Plot
sns.violinplot(x=X["make"], y=y, palette="Set3", ax=axes[1])
axes[1].set_title("Violinplot: Car Make vs Price")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-17-3339779103.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=X["make"], y=y, palette="Set2", ax=axes[0])
# /tmp/ipython-input-17-3339779103.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=X["make"], y=y, palette="Set3", ax=axes[1])

# %%
# Exercise 2
# Strip Plot
sns.stripplot(x=X["make"], y=y, jitter=True).set_title("Car Make vs Price - Strip Plot")
# Out:
# Text(0.5, 1.0, 'Car Make vs Price - Strip Plot')

# %%
# Histogram
sns.histplot(y, bins=30, kde=True).set_title("Distribution of Car Prices")
# Out:
# Text(0.5, 1.0, 'Distribution of Car Prices')

# %%
# Pair plot (for multiple feature selection)
formnumeric_cols = ['engine-size', 'curb-weight', 'horsepower', 'city-mpg', 'price']
sns.pairplot(data[numeric_cols])
